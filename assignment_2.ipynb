# %% [markdown]
# 1.What are the two values of the Boolean data type? How do you write them?
#
#    answer:
#    1. True
#    2. False
#
#
# 2. What are the three different types of Boolean operators?
#
#    answer:
#    1.AND (returns True only if both the expressions are True)
#    2.OR (returns True if one of the experession is True)
#    3.NOT (returns True if the expression is False and returns False if the expression is True)
#
#
# 3. Make a list of each Boolean operator's truth tables (i.e. every possible combination of Boolean values for the operator and what it evaluate ).
#
#     answer:
#
#      AND                                               OR                                          NOT
#
#      True and True returns True                    True and True returns True                "not True" returns False
#      True and False returns False                  True and False returns True               "not False" returns True
#      False and True returns False                  False and True returns True
#      False and False returns False                 False and False returns False
#
#
# 4. What are the values of the following expressions?
#
# (5 > 4) and (3 == 5)                     False
# not (5 > 4)                              False
# (5 > 4) or (3 == 5)                      True
# not ((5 > 4) or (3 == 5))                False  , (5>4 or 3==5) is True then  not(True) returns False
# (True and True) and (True == False)      False
# (not False) or (not True)                True
#
#
#
#
# 5. What are the six comparison operators?
#
#       == equals to      (5==5)
#       != not equals to  (6!=5)
#       > greater than    (6>5)
#       < less than       (5<6)
#       >= greater than or equal to (x=6 , x>=5)
#       <= less than or equals to   (x=7 , x<=8)
#
#
#
# 6. How do you tell the difference between the equal to and assignment operators?Describe a condition and when you would use one.
#
#      "=" is the asssignment operator and we basically use to assign a value to a variable, suppose if we need to store 5 in         variable x . we can write the code as x=5
#
#      "==" is the comparison operator and we use to check wheather both the values or expressions are equal.mostly used in if
#      statements
#      eg:
#      x=7
#      y=7
#      if (x==y):
#          print("x and y are same values")
#      else
#          print("x and y are different values")
#
#
#
# 7. Identify the three blocks in this code:
# spam = 0
# if spam == 10:
# print('eggs')
# if spam > 5:
# print('bacon')
# else:
# print('ham')
# print('spam')
# print('spam')
#
#  answer:
#          spam = 0
#          if spam == 10:
#              print('eggs')
#          if spam > 5:
#              print('bacon')
#          else:
#              print('ham')
#              print('spam')
#              print('spam')
#
#
#
# 8. Write code that prints Hello if 1 is stored in spam, prints Howdy if 2 is stored in spam, and prints Greetings! if anything else is stored in spam.
#
#        if spam == 1:
#            print("hello")
#        elif spam == 2:
#            print("howdy")
#        else:
#            print("greetings")
#
#
#
# 9.If your programme is stuck in an endless loop, what keys you’ll press?
#
#          CTRL+C (generates a keyboardinterrupt error and exits from program )
#
#
# 10. How can you tell the difference between break and continue?
#
#         break helps us to exit from the loop and continue helps us to jump to the next iteration
#
#
# 11. In a for loop, what is the difference between range(10), range(0, 10), and range(0, 10, 1)?
#
#
#        in range(10) python executes the loops until the value reaches 10 ,and it takes the staring
#        value 0 by default. we can give any other value if we want
#        in range(0,10) python will execute the loop from variable value 0 and upto 10 times .we can give other values but if
#        didint give anything , it will take the default value ie 0
#        in range(0,10,1) here python will execute loop from 0 to 10 and incrementing the value will also by 1. here also we can
#        increment the iteration value by any other number but if we didnt give any specific value ,it will take the default
#        value that is 1
#
#
#
# 12. Write a short program that prints the numbers 1 to 10 using a for loop. Then write an equivalent program that prints the numbers 1 to 10 using a while loop.
#
#        using for loop :    for x in range(1,11):
#                                 print(x)
#
#
#        using while loop:   x=1
#                            while x<=10:
#                               print(x)
#                               x+=1
#
#
#
# 13. If you had a function named bacon() inside a module named spam, how would you call it after importing spam?
#
#      answer:
#
#      import spam
#      spam.bacon()

# %%
:
