# %% [markdown]
# 1.
# In the below elements which of them are values or an expression? eg:- values can be
# integer or string and expressions will be mathematical operators.
# *
# 'hello'
# -87.8
# -
# /
# +
# 6
#
# answer :
#
# * ,-,/,+ are expressions (mathematical expressions precisely)
#
# -87.8 , 6 , 'hello' are values (floating point,integer,string respectively
#
#
# 2. What is the difference between string and variable?
#
#       variables are something that we use to store certain values or strings or any kind of informations. variable names has         some rules in python
#       strings are some collection of letters or numbers usually we mention inbetween "" , '' eg: "python",'python'
#
# 3. Describe three different data types.
#
#       three main data types in python are
#       integer (5, 10, 2) - decared as int
#       floating point (5.25, 8.0 )- declared as float
#       string ("itsmy_program",'helloworld') - declared as str
#
# 4. What is an expression made up of? What do all expressions do?
#
#     expressions are some kind of combination of values and operators .an expression should be evaluated and must return a value     (including True or False)
#
#      eg : 2+2
#         5%3
#         2>=1
#
#  5. This assignment statements, like spam = 10. What is the difference between an
# expression and a statement?
#
#       assignment statements are meant to assign some certain values to a variable for storing that value for further uses
#       but expressions are the combination of values and operators(or a specific function) which should return a value
#
#
# 6. After running the following code, what does the variable bacon contain?
# bacon = 22
# bacon + 1
#
#        answer:
#        bacon will contain the same value ie 22
#        if we need to add 1 to the variable bacon , there should be an assignmnet expression
#        bacon= bacon+1  or bacon+=1
#
# 7. What should the values of the following two terms be?
# 'spam' + 'spamspam'
# 'spam' * 3
#
#        values of both terms will be spamspamspam
#
# 8. Why is eggs a valid variable name while 100 is invalid?
#
#
#       there are certain conditions for assigning a variable name in python. variable name should not be numbers and should not       start with a number either  (can start with an underscore or a letter)
#
# 9. What three functions can be used to get the integer, floating-point number, or string version of a value?
#
#      answer:
#      int(value) - to ghet the integer version
#      float(value) - to get the floating point value
#      str(value) - to get the string version
#
# 10. Why does this expression cause an error? How can you fix it?
# 'I have eaten ' + 99 + ' burritos.'
#
#
#      answer:
#
#      99 is an integer value and it can not be concatenated with string values
#
#      we can use it like this 'I have eaten ' + '99' + ' burritos'. there are more methods though like string formatting
